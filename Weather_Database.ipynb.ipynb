# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the time library and the datetime module from the datetime library
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=12000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 776

# %%
# Import the requests library.
import requests

# Import the API key
from config3 import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retreival      ")
print("                              ")

# Create Counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    #Group cities in sets of 50 for loggin purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endponit URL with each city.
    city_url = url + '&q=' + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    #Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_describe = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_describe,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retreival
#
# Processing Record 1 of Set 1 | tura
# Processing Record 2 of Set 1 | puerto ayora
# Processing Record 3 of Set 1 | leningradskiy
# Processing Record 4 of Set 1 | katsuura
# Processing Record 5 of Set 1 | hilo
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | tres passos
# Processing Record 8 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 1 | rio brilhante
# Processing Record 10 of Set 1 | bluff
# Processing Record 11 of Set 1 | san patricio
# Processing Record 12 of Set 1 | bethel
# Processing Record 13 of Set 1 | kapaa
# Processing Record 14 of Set 1 | saint-joseph
# Processing Record 15 of Set 1 | vaini
# Processing Record 16 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 17 of Set 1 | tuktoyaktuk
# Processing Record 18 of Set 1 | kruisfontein
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | vanavara
# Processing Record 21 of Set 1 | jamestown
# Processing Record 22 of Set 1 | yellowknife
# Processing Record 23 of Set 1 | pevek
# Processing Record 24 of Set 1 | salalah
# Processing Record 25 of Set 1 | taseyevo
# Processing Record 26 of Set 1 | georgetown
# Processing Record 27 of Set 1 | geraldton
# Processing Record 28 of Set 1 | yerbogachen
# Processing Record 29 of Set 1 | avera
# Processing Record 30 of Set 1 | auki
# Processing Record 31 of Set 1 | pangnirtung
# Processing Record 32 of Set 1 | tiarei
# Processing Record 33 of Set 1 | severo-kurilsk
# Processing Record 34 of Set 1 | nouakchott
# Processing Record 35 of Set 1 | papara
# Processing Record 36 of Set 1 | hearst
# Processing Record 37 of Set 1 | gemena
# Processing Record 38 of Set 1 | manokwari
# Processing Record 39 of Set 1 | slave lake
# Processing Record 40 of Set 1 | bandarbeyla
# Processing Record 41 of Set 1 | rikitea
# Processing Record 42 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 1 | port lincoln
# Processing Record 44 of Set 1 | lexington
# Processing Record 45 of Set 1 | albany
# Processing Record 46 of Set 1 | mataura
# Processing Record 47 of Set 1 | jieshi
# Processing Record 48 of Set 1 | arraial do cabo
# Processing Record 49 of Set 1 | aklavik
# Processing Record 50 of Set 1 | victoria
# Processing Record 1 of Set 2 | wenchi
# Processing Record 2 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 2 | torbay
# Processing Record 4 of Set 2 | pinawa
# Processing Record 5 of Set 2 | port alfred
# Processing Record 6 of Set 2 | hermanus
# Processing Record 7 of Set 2 | mayumba
# Processing Record 8 of Set 2 | provideniya
# Processing Record 9 of Set 2 | nikolskoye
# Processing Record 10 of Set 2 | hobart
# Processing Record 11 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 12 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 2 | port macquarie
# Processing Record 14 of Set 2 | cherskiy
# Processing Record 15 of Set 2 | upernavik
# Processing Record 16 of Set 2 | grindavik
# Processing Record 17 of Set 2 | busselton
# Processing Record 18 of Set 2 | atuona
# Processing Record 19 of Set 2 | inhambane
# Processing Record 20 of Set 2 | chuy
# Processing Record 21 of Set 2 | marsassoum
# Processing Record 22 of Set 2 | qaqortoq
# Processing Record 23 of Set 2 | tynda
# Processing Record 24 of Set 2 | port elizabeth
# Processing Record 25 of Set 2 | mantua
# Processing Record 26 of Set 2 | olga
# Processing Record 27 of Set 2 | rudnogorsk
# Processing Record 28 of Set 2 | port blair
# Processing Record 29 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 30 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 31 of Set 2 | barrow
# Processing Record 32 of Set 2 | alyangula
# Processing Record 33 of Set 2 | naze
# Processing Record 34 of Set 2 | kaitangata
# Processing Record 35 of Set 2 | lower hutt
# Processing Record 36 of Set 2 | hasaki
# Processing Record 37 of Set 2 | new norfolk
# Processing Record 38 of Set 2 | tubuala
# Processing Record 39 of Set 2 | belmonte
# Processing Record 40 of Set 2 | qaanaaq
# Processing Record 41 of Set 2 | narsaq
# Processing Record 42 of Set 2 | ikalamavony
# Processing Record 43 of Set 2 | constitucion
# Processing Record 44 of Set 2 | nhulunbuy
# Processing Record 45 of Set 2 | xichang
# Processing Record 46 of Set 2 | chokurdakh
# Processing Record 47 of Set 2 | jalu
# Processing Record 48 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 49 of Set 2 | khatanga
# Processing Record 50 of Set 2 | kamariotissa
# Processing Record 1 of Set 3 | cabo san lucas
# Processing Record 2 of Set 3 | thompson
# Processing Record 3 of Set 3 | ushibuka
# Processing Record 4 of Set 3 | kodiak
# Processing Record 5 of Set 3 | lucapa
# Processing Record 6 of Set 3 | erzin
# Processing Record 7 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 3 | rae bareli
# Processing Record 9 of Set 3 | sioux lookout
# Processing Record 10 of Set 3 | hokitika
# Processing Record 11 of Set 3 | klaksvik
# Processing Record 12 of Set 3 | anuradhapura
# Processing Record 13 of Set 3 | zunyi
# Processing Record 14 of Set 3 | gawler
# Processing Record 15 of Set 3 | grootfontein
# Processing Record 16 of Set 3 | vila velha
# Processing Record 17 of Set 3 | paragominas
# Processing Record 18 of Set 3 | cape town
# Processing Record 19 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 20 of Set 3 | sao filipe
# Processing Record 21 of Set 3 | sitka
# Processing Record 22 of Set 3 | kailua
# Processing Record 23 of Set 3 | sokolovo
# Processing Record 24 of Set 3 | saint-augustin
# Processing Record 25 of Set 3 | mian channun
# Processing Record 26 of Set 3 | sergeyevka
# Processing Record 27 of Set 3 | koutsouras
# Processing Record 28 of Set 3 | saint-philippe
# Processing Record 29 of Set 3 | manyana
# Processing Record 30 of Set 3 | houston
# Processing Record 31 of Set 3 | jizan
# Processing Record 32 of Set 3 | hualmay
# Processing Record 33 of Set 3 | qingdao
# Processing Record 34 of Set 3 | beloha
# Processing Record 35 of Set 3 | prieska
# Processing Record 36 of Set 3 | filingue
# Processing Record 37 of Set 3 | wencheng
# Processing Record 38 of Set 3 | vagur
# Processing Record 39 of Set 3 | lieksa
# Processing Record 40 of Set 3 | takoradi
# Processing Record 41 of Set 3 | dalby
# Processing Record 42 of Set 3 | bredasdorp
# Processing Record 43 of Set 3 | castro
# Processing Record 44 of Set 3 | evansville
# Processing Record 45 of Set 3 | husavik
# Processing Record 46 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 3 | sorrento
# Processing Record 48 of Set 3 | quthing
# Processing Record 49 of Set 3 | puerto ayacucho
# Processing Record 50 of Set 3 | aquiraz
# Processing Record 1 of Set 4 | severnoye
# Processing Record 2 of Set 4 | bathsheba
# Processing Record 3 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 4 | poum
# Processing Record 5 of Set 4 | richards bay
# Processing Record 6 of Set 4 | ponta do sol
# Processing Record 7 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 8 of Set 4 | faya
# Processing Record 9 of Set 4 | maarianhamina
# Processing Record 10 of Set 4 | labuan
# Processing Record 11 of Set 4 | jiddah
# City not found. Skipping...
# Processing Record 12 of Set 4 | vardo
# Processing Record 13 of Set 4 | sawankhalok
# Processing Record 14 of Set 4 | marzuq
# Processing Record 15 of Set 4 | burnie
# Processing Record 16 of Set 4 | tabuk
# Processing Record 17 of Set 4 | kavieng
# Processing Record 18 of Set 4 | puerto carreno
# Processing Record 19 of Set 4 | tuatapere
# Processing Record 20 of Set 4 | maneadero
# Processing Record 21 of Set 4 | longyearbyen
# Processing Record 22 of Set 4 | elizabeth city
# Processing Record 23 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 24 of Set 4 | pokhara
# Processing Record 25 of Set 4 | tiksi
# Processing Record 26 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 27 of Set 4 | ust-maya
# Processing Record 28 of Set 4 | limon
# Processing Record 29 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 4 | honningsvag
# Processing Record 31 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 4 | gobabis
# Processing Record 33 of Set 4 | dobsina
# Processing Record 34 of Set 4 | samarai
# Processing Record 35 of Set 4 | straz pod ralskem
# Processing Record 36 of Set 4 | fare
# Processing Record 37 of Set 4 | mount gambier
# Processing Record 38 of Set 4 | mahebourg
# Processing Record 39 of Set 4 | baykit
# Processing Record 40 of Set 4 | alta floresta
# Processing Record 41 of Set 4 | tkvarcheli
# City not found. Skipping...
# Processing Record 42 of Set 4 | vostok
# Processing Record 43 of Set 4 | marathon
# Processing Record 44 of Set 4 | mar del plata
# Processing Record 45 of Set 4 | martinsville
# Processing Record 46 of Set 4 | atar
# Processing Record 47 of Set 4 | lasa
# Processing Record 48 of Set 4 | ha giang
# Processing Record 49 of Set 4 | san jeronimo
# Processing Record 50 of Set 4 | saskylakh
# Processing Record 1 of Set 5 | bonthe
# Processing Record 2 of Set 5 | zenzeli
# Processing Record 3 of Set 5 | paamiut
# Processing Record 4 of Set 5 | korla
# Processing Record 5 of Set 5 | bambous virieux
# Processing Record 6 of Set 5 | flinders
# Processing Record 7 of Set 5 | hami
# Processing Record 8 of Set 5 | dikson
# Processing Record 9 of Set 5 | lodja
# Processing Record 10 of Set 5 | nemuro
# Processing Record 11 of Set 5 | iqaluit
# Processing Record 12 of Set 5 | keningau
# Processing Record 13 of Set 5 | hofn
# Processing Record 14 of Set 5 | san cristobal
# Processing Record 15 of Set 5 | mandalgovi
# Processing Record 16 of Set 5 | tessalit
# Processing Record 17 of Set 5 | santa cruz del sur
# Processing Record 18 of Set 5 | skjervoy
# Processing Record 19 of Set 5 | adrar
# Processing Record 20 of Set 5 | hithadhoo
# Processing Record 21 of Set 5 | isangel
# Processing Record 22 of Set 5 | churapcha
# Processing Record 23 of Set 5 | zhigansk
# Processing Record 24 of Set 5 | laguna
# Processing Record 25 of Set 5 | clyde river
# Processing Record 26 of Set 5 | san fernando
# Processing Record 27 of Set 5 | ejido
# Processing Record 28 of Set 5 | kiama
# Processing Record 29 of Set 5 | avarua
# Processing Record 30 of Set 5 | manacor
# Processing Record 31 of Set 5 | cidreira
# Processing Record 32 of Set 5 | vila franca do campo
# Processing Record 33 of Set 5 | carnarvon
# Processing Record 34 of Set 5 | souillac
# Processing Record 35 of Set 5 | esperance
# Processing Record 36 of Set 5 | surazh
# Processing Record 37 of Set 5 | kamaishi
# Processing Record 38 of Set 5 | wukari
# Processing Record 39 of Set 5 | noumea
# Processing Record 40 of Set 5 | airai
# Processing Record 41 of Set 5 | necochea
# Processing Record 42 of Set 5 | chumphon
# Processing Record 43 of Set 5 | byron bay
# Processing Record 44 of Set 5 | borama
# City not found. Skipping...
# Processing Record 45 of Set 5 | nuevo progreso
# Processing Record 46 of Set 5 | praia da vitoria
# Processing Record 47 of Set 5 | vestmanna
# Processing Record 48 of Set 5 | perote
# Processing Record 49 of Set 5 | qasigiannguit
# Processing Record 50 of Set 5 | chamba
# Processing Record 1 of Set 6 | coquimbo
# Processing Record 2 of Set 6 | komsomolskiy
# Processing Record 3 of Set 6 | butaritari
# Processing Record 4 of Set 6 | pitimbu
# Processing Record 5 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 6 | busembatia
# Processing Record 7 of Set 6 | lalsk
# Processing Record 8 of Set 6 | neiafu
# Processing Record 9 of Set 6 | nuuk
# Processing Record 10 of Set 6 | stornoway
# Processing Record 11 of Set 6 | saldanha
# Processing Record 12 of Set 6 | samarinda
# Processing Record 13 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 14 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 15 of Set 6 | mpika
# Processing Record 16 of Set 6 | camacha
# Processing Record 17 of Set 6 | peterborough
# Processing Record 18 of Set 6 | bengkulu
# Processing Record 19 of Set 6 | zeya
# Processing Record 20 of Set 6 | vilcun
# Processing Record 21 of Set 6 | chapais
# Processing Record 22 of Set 6 | portobelo
# Processing Record 23 of Set 6 | kadykchan
# City not found. Skipping...
# Processing Record 24 of Set 6 | ilinge
# Processing Record 25 of Set 6 | mount isa
# Processing Record 26 of Set 6 | hun
# Processing Record 27 of Set 6 | broome
# Processing Record 28 of Set 6 | tautira
# Processing Record 29 of Set 6 | chumikan
# Processing Record 30 of Set 6 | banikoara
# Processing Record 31 of Set 6 | atasu
# Processing Record 32 of Set 6 | oudtshoorn
# Processing Record 33 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 6 | lazaro cardenas
# Processing Record 35 of Set 6 | tasiilaq
# Processing Record 36 of Set 6 | grand gaube
# Processing Record 37 of Set 6 | chaoyang
# Processing Record 38 of Set 6 | mwanza
# Processing Record 39 of Set 6 | kollumerland
# City not found. Skipping...
# Processing Record 40 of Set 6 | shubarkuduk
# Processing Record 41 of Set 6 | rush
# Processing Record 42 of Set 6 | palencia
# Processing Record 43 of Set 6 | boende
# Processing Record 44 of Set 6 | antofagasta
# Processing Record 45 of Set 6 | starachowice
# Processing Record 46 of Set 6 | general roca
# Processing Record 47 of Set 6 | chippewa falls
# Processing Record 48 of Set 6 | waddan
# Processing Record 49 of Set 6 | ampanihy
# Processing Record 50 of Set 6 | saint george
# Processing Record 1 of Set 7 | alofi
# Processing Record 2 of Set 7 | nome
# Processing Record 3 of Set 7 | fort wellington
# Processing Record 4 of Set 7 | foso
# Processing Record 5 of Set 7 | itaituba
# Processing Record 6 of Set 7 | gat
# Processing Record 7 of Set 7 | westport
# Processing Record 8 of Set 7 | giyani
# Processing Record 9 of Set 7 | lorengau
# Processing Record 10 of Set 7 | bandiagara
# Processing Record 11 of Set 7 | faanui
# Processing Record 12 of Set 7 | vestmannaeyjar
# Processing Record 13 of Set 7 | huainan
# Processing Record 14 of Set 7 | luena
# Processing Record 15 of Set 7 | anadyr
# Processing Record 16 of Set 7 | sibenik
# Processing Record 17 of Set 7 | koumac
# Processing Record 18 of Set 7 | kabugao
# Processing Record 19 of Set 7 | baruun-urt
# Processing Record 20 of Set 7 | rawson
# Processing Record 21 of Set 7 | gofitskoye
# Processing Record 22 of Set 7 | gushikawa
# Processing Record 23 of Set 7 | sukhothai
# Processing Record 24 of Set 7 | aberdeen
# Processing Record 25 of Set 7 | galle
# Processing Record 26 of Set 7 | ponta delgada
# Processing Record 27 of Set 7 | sao felix do xingu
# Processing Record 28 of Set 7 | cacahoatan
# Processing Record 29 of Set 7 | altamira
# Processing Record 30 of Set 7 | cockburn town
# Processing Record 31 of Set 7 | ust-nera
# Processing Record 32 of Set 7 | lebu
# Processing Record 33 of Set 7 | shuya
# Processing Record 34 of Set 7 | shangrao
# Processing Record 35 of Set 7 | popondetta
# Processing Record 36 of Set 7 | shingu
# Processing Record 37 of Set 7 | hovd
# Processing Record 38 of Set 7 | mayskiy
# Processing Record 39 of Set 7 | khurianwala
# City not found. Skipping...
# Processing Record 40 of Set 7 | berlevag
# Processing Record 41 of Set 7 | abeche
# Processing Record 42 of Set 7 | port hawkesbury
# Processing Record 43 of Set 7 | dolores
# Processing Record 44 of Set 7 | codrington
# Processing Record 45 of Set 7 | butembo
# Processing Record 46 of Set 7 | inongo
# Processing Record 47 of Set 7 | tammisaari
# Processing Record 48 of Set 7 | axim
# Processing Record 49 of Set 7 | hudson bay
# Processing Record 50 of Set 7 | namatanai
# Processing Record 1 of Set 8 | kilindoni
# Processing Record 2 of Set 8 | hongjiang
# Processing Record 3 of Set 8 | kaiserslautern
# Processing Record 4 of Set 8 | nishihara
# Processing Record 5 of Set 8 | tokur
# Processing Record 6 of Set 8 | east london
# Processing Record 7 of Set 8 | staronizhestebliyevskaya
# Processing Record 8 of Set 8 | ancud
# Processing Record 9 of Set 8 | lagoa
# Processing Record 10 of Set 8 | verkhoyansk
# Processing Record 11 of Set 8 | abyek
# Processing Record 12 of Set 8 | muzaffarabad
# Processing Record 13 of Set 8 | arkhangelsk
# Processing Record 14 of Set 8 | olathe
# Processing Record 15 of Set 8 | pontecorvo
# Processing Record 16 of Set 8 | shelburne
# Processing Record 17 of Set 8 | yithion
# City not found. Skipping...
# Processing Record 18 of Set 8 | solok
# Processing Record 19 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 20 of Set 8 | malanje
# Processing Record 21 of Set 8 | roald
# Processing Record 22 of Set 8 | rio grande
# Processing Record 23 of Set 8 | beli potok
# Processing Record 24 of Set 8 | olafsvik
# Processing Record 25 of Set 8 | college
# Processing Record 26 of Set 8 | tromso
# Processing Record 27 of Set 8 | shenkursk
# Processing Record 28 of Set 8 | coihaique
# Processing Record 29 of Set 8 | praya
# Processing Record 30 of Set 8 | bam
# Processing Record 31 of Set 8 | asau
# Processing Record 32 of Set 8 | grande-riviere
# City not found. Skipping...
# Processing Record 33 of Set 8 | hobyo
# Processing Record 34 of Set 8 | sorland
# Processing Record 35 of Set 8 | salinopolis
# Processing Record 36 of Set 8 | poopo
# Processing Record 37 of Set 8 | fort saint james
# Processing Record 38 of Set 8 | esso
# Processing Record 39 of Set 8 | bisert
# Processing Record 40 of Set 8 | abu samrah
# Processing Record 41 of Set 8 | yatou
# Processing Record 42 of Set 8 | ceres
# Processing Record 43 of Set 8 | gouyave
# Processing Record 44 of Set 8 | dudinka
# Processing Record 45 of Set 8 | ilulissat
# Processing Record 46 of Set 8 | durango
# Processing Record 47 of Set 8 | baker city
# Processing Record 48 of Set 8 | moron
# Processing Record 49 of Set 8 | cascais
# Processing Record 50 of Set 8 | jackson
# Processing Record 1 of Set 9 | vao
# Processing Record 2 of Set 9 | izhma
# Processing Record 3 of Set 9 | jawhar
# Processing Record 4 of Set 9 | oktyabrskoye
# Processing Record 5 of Set 9 | egvekinot
# Processing Record 6 of Set 9 | ibra
# Processing Record 7 of Set 9 | chichigalpa
# Processing Record 8 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 9 of Set 9 | kamenka
# Processing Record 10 of Set 9 | vanimo
# Processing Record 11 of Set 9 | kidal
# Processing Record 12 of Set 9 | kaspiyskiy
# Processing Record 13 of Set 9 | geresk
# City not found. Skipping...
# Processing Record 14 of Set 9 | sosua
# Processing Record 15 of Set 9 | aleksandrovskiy zavod
# Processing Record 16 of Set 9 | indramayu
# Processing Record 17 of Set 9 | panzhihua
# Processing Record 18 of Set 9 | alakurtti
# Processing Record 19 of Set 9 | sayat
# Processing Record 20 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 21 of Set 9 | buala
# Processing Record 22 of Set 9 | kayunga
# Processing Record 23 of Set 9 | maridi
# Processing Record 24 of Set 9 | vienne
# Processing Record 25 of Set 9 | carroll
# Processing Record 26 of Set 9 | koubia
# Processing Record 27 of Set 9 | rocha
# Processing Record 28 of Set 9 | acajutla
# Processing Record 29 of Set 9 | el tigre
# Processing Record 30 of Set 9 | mayo
# Processing Record 31 of Set 9 | muros
# Processing Record 32 of Set 9 | srostki
# Processing Record 33 of Set 9 | port hardy
# Processing Record 34 of Set 9 | great bend
# Processing Record 35 of Set 9 | hambantota
# Processing Record 36 of Set 9 | kaeo
# Processing Record 37 of Set 9 | sobolevo
# Processing Record 38 of Set 9 | copiapo
# Processing Record 39 of Set 9 | ambilobe
# Processing Record 40 of Set 9 | khuzhir
# Processing Record 41 of Set 9 | cayenne
# Processing Record 42 of Set 9 | kannur
# Processing Record 43 of Set 9 | orel-izumrud
# Processing Record 44 of Set 9 | kuvshinovo
# Processing Record 45 of Set 9 | tambacounda
# Processing Record 46 of Set 9 | murmashi
# Processing Record 47 of Set 9 | haines junction
# Processing Record 48 of Set 9 | nyagan
# Processing Record 49 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 50 of Set 9 | shaunavon
# Processing Record 1 of Set 10 | fairbanks
# Processing Record 2 of Set 10 | humaita
# Processing Record 3 of Set 10 | sinop
# Processing Record 4 of Set 10 | sawtell
# Processing Record 5 of Set 10 | sovetskiy
# Processing Record 6 of Set 10 | arman
# Processing Record 7 of Set 10 | salekhard
# Processing Record 8 of Set 10 | golden
# Processing Record 9 of Set 10 | port-gentil
# Processing Record 10 of Set 10 | hamilton
# Processing Record 11 of Set 10 | nanchang
# Processing Record 12 of Set 10 | lufilufi
# Processing Record 13 of Set 10 | sabang
# Processing Record 14 of Set 10 | chichicapam
# City not found. Skipping...
# Processing Record 15 of Set 10 | florianopolis
# Processing Record 16 of Set 10 | portland
# Processing Record 17 of Set 10 | kupino
# Processing Record 18 of Set 10 | olot
# Processing Record 19 of Set 10 | xinzhou
# Processing Record 20 of Set 10 | fomboni
# Processing Record 21 of Set 10 | tidore
# City not found. Skipping...
# Processing Record 22 of Set 10 | fortuna
# Processing Record 23 of Set 10 | tabou
# Processing Record 24 of Set 10 | armacao dos buzios
# City not found. Skipping...
# Processing Record 25 of Set 10 | anamur
# Processing Record 26 of Set 10 | marseille
# Processing Record 27 of Set 10 | diu
# Processing Record 28 of Set 10 | yulara
# Processing Record 29 of Set 10 | bassar
# Processing Record 30 of Set 10 | maun
# Processing Record 31 of Set 10 | lavrentiya
# Processing Record 32 of Set 10 | namibe
# Processing Record 33 of Set 10 | ballina
# Processing Record 34 of Set 10 | ailigandi
# Processing Record 35 of Set 10 | charters towers
# Processing Record 36 of Set 10 | gizo
# Processing Record 37 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 38 of Set 10 | yarke pole
# Processing Record 39 of Set 10 | mao
# Processing Record 40 of Set 10 | araouane
# Processing Record 41 of Set 10 | sinazongwe
# Processing Record 42 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 43 of Set 10 | luderitz
# Processing Record 44 of Set 10 | mlandizi
# Processing Record 45 of Set 10 | sinkat
# City not found. Skipping...
# Processing Record 46 of Set 10 | price
# Processing Record 47 of Set 10 | kalmunai
# Processing Record 48 of Set 10 | saint anthony
# Processing Record 49 of Set 10 | benghazi
# Processing Record 50 of Set 10 | yoichi
# Processing Record 1 of Set 11 | belle fourche
# Processing Record 2 of Set 11 | betanzos
# Processing Record 3 of Set 11 | skibbereen
# Processing Record 4 of Set 11 | mackay
# Processing Record 5 of Set 11 | sao joao da barra
# Processing Record 6 of Set 11 | hima
# Processing Record 7 of Set 11 | jiayuguan
# Processing Record 8 of Set 11 | mongo
# Processing Record 9 of Set 11 | envira
# Processing Record 10 of Set 11 | tarabuco
# Processing Record 11 of Set 11 | yei
# Processing Record 12 of Set 11 | kyabram
# Processing Record 13 of Set 11 | silopi
# Processing Record 14 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 15 of Set 11 | ayotzintepec
# Processing Record 16 of Set 11 | umm lajj
# Processing Record 17 of Set 11 | stadskanaal
# Processing Record 18 of Set 11 | anuppur
# Processing Record 19 of Set 11 | panjab
# Processing Record 20 of Set 11 | ginda
# Processing Record 21 of Set 11 | trelew
# Processing Record 22 of Set 11 | chara
# Processing Record 23 of Set 11 | reconquista
# Processing Record 24 of Set 11 | damietta
# Processing Record 25 of Set 11 | kankakee
# Processing Record 26 of Set 11 | uyaan
# Processing Record 27 of Set 11 | ringebu
# Processing Record 28 of Set 11 | darayya
# Processing Record 29 of Set 11 | half moon bay
# Processing Record 30 of Set 11 | yeppoon
# Processing Record 31 of Set 11 | ostrovnoy
# Processing Record 32 of Set 11 | puerto guzman
# Processing Record 33 of Set 11 | makokou
# Processing Record 34 of Set 11 | zhigalovo
# Processing Record 35 of Set 11 | beihai
# Processing Record 36 of Set 11 | minador do negrao
# Processing Record 37 of Set 11 | dingle
# Processing Record 38 of Set 11 | sangar
# Processing Record 39 of Set 11 | pousat
# City not found. Skipping...
# Processing Record 40 of Set 11 | mwinilunga
# Processing Record 41 of Set 11 | gravdal
# Processing Record 42 of Set 11 | ratnagiri
# Processing Record 43 of Set 11 | cloquet
# Processing Record 44 of Set 11 | takhtamygda
# Processing Record 45 of Set 11 | sibu
# Processing Record 46 of Set 11 | tankhoy
# Processing Record 47 of Set 11 | vavoua
# Processing Record 48 of Set 11 | qandahar
# City not found. Skipping...
# Processing Record 49 of Set 11 | praia
# Processing Record 50 of Set 11 | alice springs
# Processing Record 1 of Set 12 | sataua
# City not found. Skipping...
# Processing Record 2 of Set 12 | caravelas
# Processing Record 3 of Set 12 | bilibino
# Processing Record 4 of Set 12 | sarankhola
# Processing Record 5 of Set 12 | okha
# Processing Record 6 of Set 12 | raga
# Processing Record 7 of Set 12 | lloydminster
# Processing Record 8 of Set 12 | loa janan
# Processing Record 9 of Set 12 | loreto
# Processing Record 10 of Set 12 | sur
# Processing Record 11 of Set 12 | sumenep
# Processing Record 12 of Set 12 | nizhneyansk
# City not found. Skipping...
# Processing Record 13 of Set 12 | dombarovskiy
# Processing Record 14 of Set 12 | mushie
# Processing Record 15 of Set 12 | mayahi
# Processing Record 16 of Set 12 | manta
# Processing Record 17 of Set 12 | ribeira grande
# Processing Record 18 of Set 12 | henties bay
# Processing Record 19 of Set 12 | kathmandu
# Processing Record 20 of Set 12 | port hedland
# Processing Record 21 of Set 12 | varzea grande
# Processing Record 22 of Set 12 | narang
# Processing Record 23 of Set 12 | xiuyan
# Processing Record 24 of Set 12 | yinchuan
# Processing Record 25 of Set 12 | magdagachi
# Processing Record 26 of Set 12 | sandnessjoen
# Processing Record 27 of Set 12 | putyatino
# Processing Record 28 of Set 12 | valley city
# Processing Record 29 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 30 of Set 12 | clifton
# Processing Record 31 of Set 12 | yuli
# Processing Record 32 of Set 12 | christchurch
# Processing Record 33 of Set 12 | aksu
# Processing Record 34 of Set 12 | waingapu
# Processing Record 35 of Set 12 | almunecar
# Processing Record 36 of Set 12 | aktash
# Processing Record 37 of Set 12 | sambava
# Processing Record 38 of Set 12 | ixtapa
# Processing Record 39 of Set 12 | acarau
# Processing Record 40 of Set 12 | kushmurun
# Processing Record 41 of Set 12 | savannah bight
# Processing Record 42 of Set 12 | palmer
# Processing Record 43 of Set 12 | yarada
# Processing Record 44 of Set 12 | sept-iles
# Processing Record 45 of Set 12 | monaghan
# Processing Record 46 of Set 12 | nago
# Processing Record 47 of Set 12 | ateli
# Processing Record 48 of Set 12 | eidsvag
# Processing Record 49 of Set 12 | puerto escondido
# Processing Record 50 of Set 12 | pagegiai
# Processing Record 1 of Set 13 | takanosu
# Processing Record 2 of Set 13 | dali
# Processing Record 3 of Set 13 | taber
# Processing Record 4 of Set 13 | gubkinskiy
# Processing Record 5 of Set 13 | eldorado
# Processing Record 6 of Set 13 | valdemarpils
# Processing Record 7 of Set 13 | hit
# Processing Record 8 of Set 13 | edgemoor
# Processing Record 9 of Set 13 | karauzyak
# City not found. Skipping...
# Processing Record 10 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 11 of Set 13 | kimbe
# Processing Record 12 of Set 13 | hayden
# Processing Record 13 of Set 13 | staryy nadym
# Processing Record 14 of Set 13 | aksarka
# Processing Record 15 of Set 13 | carndonagh
# Processing Record 16 of Set 13 | bobonong
# City not found. Skipping...
# Processing Record 17 of Set 13 | amparafaravola
# Processing Record 18 of Set 13 | guerrero negro
# Processing Record 19 of Set 13 | kisangani
# Processing Record 20 of Set 13 | orlik
# Processing Record 21 of Set 13 | linhares
# Processing Record 22 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 23 of Set 13 | ler
# Processing Record 24 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 25 of Set 13 | linchuan
# City not found. Skipping...
# Processing Record 26 of Set 13 | lipari
# Processing Record 27 of Set 13 | shache
# Processing Record 28 of Set 13 | barawe
# City not found. Skipping...
# Processing Record 29 of Set 13 | kutum
# Processing Record 30 of Set 13 | farmington
# Processing Record 31 of Set 13 | wanning
# Processing Record 32 of Set 13 | okahandja
# Processing Record 33 of Set 13 | plettenberg bay
# Processing Record 34 of Set 13 | muisne
# Processing Record 35 of Set 13 | kolpny
# Processing Record 36 of Set 13 | sivas
# Processing Record 37 of Set 13 | kahului
# Processing Record 38 of Set 13 | balkhash
# Processing Record 39 of Set 13 | mlalo
# Processing Record 40 of Set 13 | xuddur
# Processing Record 41 of Set 13 | urumqi
# Processing Record 42 of Set 13 | chifeng
# Processing Record 43 of Set 13 | brahmapuri
# City not found. Skipping...
# Processing Record 44 of Set 13 | srednekolymsk
# Processing Record 45 of Set 13 | ayagoz
# Processing Record 46 of Set 13 | upington
# Processing Record 47 of Set 13 | pitmoaga
# Processing Record 48 of Set 13 | shimoda
# Processing Record 49 of Set 13 | beringovskiy
# Processing Record 50 of Set 13 | kiboga
# Processing Record 1 of Set 14 | calbuco
# Processing Record 2 of Set 14 | balimo
# City not found. Skipping...
# Processing Record 3 of Set 14 | stejaru
# Processing Record 4 of Set 14 | darnah
# Processing Record 5 of Set 14 | feldkirchen
# Processing Record 6 of Set 14 | cap malheureux
# Processing Record 7 of Set 14 | acapulco
# Processing Record 8 of Set 14 | marquette
# Processing Record 9 of Set 14 | matara
# Processing Record 10 of Set 14 | echternach
# Processing Record 11 of Set 14 | batagay
# Processing Record 12 of Set 14 | barroquinha
# Processing Record 13 of Set 14 | poya
# Processing Record 14 of Set 14 | alotau
# City not found. Skipping...
# Processing Record 15 of Set 14 | jiangyou
# Processing Record 16 of Set 14 | mardin
# Processing Record 17 of Set 14 | talavera de la reina
# Processing Record 18 of Set 14 | ranong
# Processing Record 19 of Set 14 | mugur-aksy
# Processing Record 20 of Set 14 | savelugu
# Processing Record 21 of Set 14 | salyan
# Processing Record 22 of Set 14 | maniitsoq
# Processing Record 23 of Set 14 | barcelos
# Processing Record 24 of Set 14 | havoysund
# Processing Record 25 of Set 14 | dolinsk
# Processing Record 26 of Set 14 | alamos
# Processing Record 27 of Set 14 | ghanzi
# Processing Record 28 of Set 14 | denizli
# Processing Record 29 of Set 14 | amga
# Processing Record 30 of Set 14 | salina
# Processing Record 31 of Set 14 | vung tau
# Processing Record 32 of Set 14 | makakilo city
# Processing Record 33 of Set 14 | zaranj
# Processing Record 34 of Set 14 | victor harbor
# Processing Record 35 of Set 14 | changji
# Processing Record 36 of Set 14 | san policarpo
# Processing Record 37 of Set 14 | linjiang
# Processing Record 38 of Set 14 | san andres
# Processing Record 39 of Set 14 | devarkonda
# Processing Record 40 of Set 14 | kuzino
# Processing Record 41 of Set 14 | fershampenuaz
# Processing Record 42 of Set 14 | bani
# Processing Record 43 of Set 14 | saint-ambroise
# Processing Record 44 of Set 14 | japura
# Processing Record 45 of Set 14 | daugai
# Processing Record 46 of Set 14 | qala
# Processing Record 47 of Set 14 | sao jose da coroa grande
# Processing Record 48 of Set 14 | cedar city
# Processing Record 49 of Set 14 | megion
# Processing Record 50 of Set 14 | montrose
# Processing Record 1 of Set 15 | taoudenni
# Processing Record 2 of Set 15 | shenzhen
# Processing Record 3 of Set 15 | ye
# City not found. Skipping...
# Processing Record 4 of Set 15 | ugoofaaru
# Processing Record 5 of Set 15 | hailar
# Processing Record 6 of Set 15 | ondjiva
# Processing Record 7 of Set 15 | touros
# Processing Record 8 of Set 15 | zyryanka
# Processing Record 9 of Set 15 | tiznit
# Processing Record 10 of Set 15 | antigonish
# Processing Record 11 of Set 15 | san ramon
# Processing Record 12 of Set 15 | usinsk
# Processing Record 13 of Set 15 | corinth
# Processing Record 14 of Set 15 | syamzha
# Processing Record 15 of Set 15 | bilma
# Processing Record 16 of Set 15 | amuntai
# Processing Record 17 of Set 15 | cifuentes
# Processing Record 18 of Set 15 | mehamn
# Processing Record 19 of Set 15 | abha
# Processing Record 20 of Set 15 | saint-pierre
# Processing Record 21 of Set 15 | chatra
# Processing Record 22 of Set 15 | coulihaut
# City not found. Skipping...
# Processing Record 23 of Set 15 | hirara
# Processing Record 24 of Set 15 | ahipara
# Processing Record 25 of Set 15 | dunedin
# Processing Record 26 of Set 15 | talcahuano
# Processing Record 27 of Set 15 | dobrinka
# Processing Record 28 of Set 15 | eureka
# Processing Record 29 of Set 15 | karratha
# Processing Record 30 of Set 15 | clive
# Processing Record 31 of Set 15 | khani
# Processing Record 32 of Set 15 | rawannawi
# City not found. Skipping...
# Processing Record 33 of Set 15 | katobu
# Processing Record 34 of Set 15 | mbacke
# City not found. Skipping...
# Processing Record 35 of Set 15 | khandyga
# Processing Record 36 of Set 15 | baoro
# Processing Record 37 of Set 15 | middle island
# Processing Record 38 of Set 15 | nam tha
# City not found. Skipping...
# Processing Record 39 of Set 15 | algeciras
# Processing Record 40 of Set 15 | kendari
# Processing Record 41 of Set 15 | altus
# Processing Record 42 of Set 15 | youghal
# Processing Record 43 of Set 15 | tenabo
# Processing Record 44 of Set 15 | shkotovo-26
# City not found. Skipping...
# Processing Record 45 of Set 15 | sinnamary
# Processing Record 46 of Set 15 | quelimane
# Processing Record 47 of Set 15 | kati
# Processing Record 48 of Set 15 | magole
# Processing Record 49 of Set 15 | guliston
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
 city_weather = requests.get(city_url).json()
        # Parse out the needed data.
city_lat = city_weather["coord"]["lat"]
city_lng = city_weather["coord"]["lon"]
city_max_temp = city_weather["main"]["temp_max"]
city_humidity = city_weather["main"]["humidity"]
city_clouds = city_weather["clouds"]["all"]
city_wind = city_weather["wind"]["speed"]
city_describe = city_weather["weather"][0]["description"]
city_country = city_weather["sys"]["country"]
        
        # Convert the date to ISO standard.
city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
      # Append the city information into city_data list.
city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_describe,
                          "Country": city_country,
                          "Date": city_date})

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8756/3249138542.py in <module>
#       1 # Convert the array of dictionaries to a Pandas DataFrame.
# ----> 2 city_data_df = pd.DataFrame(city_data)
#       3 new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description"]
#       4 city_data_df = city_data_df[new_column_order]
#       5 city_data_df.head(10)
#
# NameError: name 'city_data' is not defined

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database.ipynb/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8756/2231423593.py in <module>
#       2 output_data_file = "Weather_Database.ipynb/WeatherPy_Database.csv"
#       3 # Export the City_Data into a CSV.
# ----> 4 city_data_df.to_csv(output_data_file, index_label="City_ID")
#
# NameError: name 'city_data_df' is not defined
